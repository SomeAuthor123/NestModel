# %%
import networkx as nx

# %%
G1 = nx.DiGraph([(0,1),(1,2),(2,0), (0,3), (0,4)])

# %%
nx.draw(G1)

# %%
nx.pagerank(G1,tol=1e-20)
# Out:
# {0: 0.278534692772715,
#  1: 0.16502751962465037,
#  2: 0.22638274835333394,
#  3: 0.16502751962465037,
#  4: 0.16502751962465037}

# %%
G2 = nx.DiGraph([(0,1),(1,2),(2,0), (0,3), (1,4)])

# %%
nx.draw(G2)

# %%
nx.pagerank(G2,tol=1e-20)
# Out:
# {0: 0.24583101723179543,
#  1: 0.19858254585881047,
#  2: 0.17850194552529183,
#  3: 0.19858254585881047,
#  4: 0.17850194552529183}

# %%
from cc_model.wl import WL

# %%
WL(G1)
# Out:
# (1, [array([0, 0, 0, 0, 0])])

# %%
WL(G2)
# Out:
# (1, [array([0, 0, 0, 0, 0])])
